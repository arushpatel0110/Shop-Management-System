# %%
## import random
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def __str__(self):
        return f"- {self.name} (Price: ${self.price}, Quantity: {self.quantity})"


class Book(Product):
    def __init__(self, name, price, quantity, author):
        super().__init__(name, price, quantity)
        self.author = author

class TShirt(Product):
    def __init__(self, name, price, quantity, size, color):
        super().__init__(name, price, quantity)
        self.size = size
        self.color = color
        
class Shoes(Product):
    def __init__(self, name, price, quantity, size, color):
        super().__init__(name, price, quantity)
        self.size = size
        self.color = color
        
class Pants(Product):
    def __init__(self, name, price, quantity, waist, length):
        super().__init__(name, price, quantity)
        self.waist = waist
        self.length = length
        
class Smartwatch(Product):
    def __init__(self, name, price, quantity, brand, model, battery):
        super().__init__(name, price, quantity)
        self.brand = brand
        self.model = model
        self.battery = battery
        
class TV(Product):
    def __init__(self, name, price, quantity, brand, size, resolution):
        super().__init__(name, price, quantity)
        self.brand = brand
        self.size = size
        self.resolution = resolution

class Inventory:
    def __init__(self, capacity=1000):
        self.capacity = capacity
        self.products = []
        self.cart=[]
        self.user=[]
        self.mobile=[]
        self.address=[]
        
    def add_product_book(self, product):
        if len(self.products) < self.capacity:
            self.products.append(product)
        else:
            print("Inventory is full.")
    
    def add_product_tshirt(self, product):
        if len(self.products) < self.capacity:
            self.products.append(product)
        else:
            print("Inventory is full.")
            
    def add_product_shoes(self, product):
        if len(self.products) < self.capacity:
            self.products.append(product)
        else:
            print("Inventory is full.")
            
    def add_product_pants(self, product):
        if len(self.products) < self.capacity:
            self.products.append(product)
        else:
            print("Inventory is full.")
            
    def add_product_smartwatch(self, product):
        if len(self.products) < self.capacity:
            self.products.append(product)
        else:
            print("Inventory is full.")
            
    def add_product_tv(self, product):
        if len(self.products) < self.capacity:
            self.products.append(product)
        else:
            print("Inventory is full.")
            
    def display_products(self):
        if not self.products:
            print("Inventory is empty.")
        else:
            print("\nProducts in inventory:")
            print("----------------------------------------------")
            for product in self.products:
                print(f"Name: {product.name}")
                print(f"Price: ${product.price}")
                print(f"Quantity: {product.quantity}")
                if isinstance(product, Book):
                    print(f"Author: {product.author}")
                    print("----------------------------------------------")
                elif isinstance(product, TShirt):
                    print(f"Size: {product.size}")
                    
                    print(f"Color: {product.color}")
                    print("----------------------------------------------")
                elif isinstance(product, Shoes):
                    print(f"Size: {product.size}")
                    print(f"Color: {product.color}")
                    print("----------------------------------------------")
                elif isinstance(product, Pants):
                    print(f"Waist: {product.waist}")
                    print(f"Length: {product.length}")
                    print("----------------------------------------------")
                elif isinstance(product, Smartwatch):
                    print(f"Brand: {product.brand}")
                    print(f"Model: {product.model}")
                    print(f"Battery: {product.battery}")
                    print("----------------------------------------------")
                elif isinstance(product, TV):
                    print(f"Brand: {product.brand}")
                    print(f"Size: {product.size} inches")
                    print(f"Resolution: {product.resolution}")
                    print("----------------------------------------------")
    
    def display_products_books(self):
        if not self.products:
            print("Inventory is empty.")
        else:
            print("\nBooks in inventory:")
            print("----------------------------------------------")
            for product in self.products:
                if isinstance(product, Book):
                    print(f"Name: {product.name}")
                    print(f"Price: ${product.price}")
                    print(f"Quantity: {product.quantity}")
                    print(f"Author: {product.author}")
                    print("----------------------------------------------")
                
    def display_products_tshirt(self):
        if not self.products:
            print("Inventory is empty.")
        else:
            print("\nT-Shirts in inventory:")
            print("----------------------------------------------")
            for product in self.products:
                if isinstance(product, TShirt):
                    print(f"Name: {product.name}")
                    print(f"Price: ${product.price}")
                    print(f"Quantity: {product.quantity}")
                    print(f"Size: {product.size}")
                    print(f"Color: {product.color}")
                    print("----------------------------------------------")
                
    def display_products_shoes(self):
        if not self.products:
            print("Inventory is empty.")
        else:
            print("\nShoes in inventory:")
            print("----------------------------------------------")
            for product in self.products:
                if isinstance(product, Shoes):
                    print(f"Name: {product.name}")
                    print(f"Price: ${product.price}")
                    print(f"Quantity: {product.quantity}")
                    print(f"Size: {product.size}")
                    print(f"Color: {product.color}")
                    print("----------------------------------------------")

    def display_products_pants(self):
        if not self.products:
            print("Inventory is empty.")
        else:
            print("\nPants in inventory:")
            print("----------------------------------------------")
            for product in self.products:
                if isinstance(product, Pants):
                    print(f"Name: {product.name}")
                    print(f"Price: ${product.price}")
                    print(f"Quantity: {product.quantity}")
                    print(f"Waist: {product.waist}")
                    print(f"Length: {product.length}")
                    print("----------------------------------------------")
                
    def display_products_smartwatch(self):
        if not self.products:
            print("Inventory is empty.")
        else:
            print("\nSmartwatches in inventory:")
            print("----------------------------------------------")
            for product in self.products:
                if isinstance(product, Smartwatch):
                    print(f"Name: {product.name}")
                    print(f"Price: ${product.price}")
                    print(f"Quantity: {product.quantity}")
                    print(f"Brand: {product.brand}")
                    print(f"Model: {product.model}")
                    print(f"Battery: {product.battery}")
                    print("----------------------------------------------")
                
    def display_products_tv(self):
        if not self.products:
            print("Inventory is empty.")
        else:
            print("\nTVs in inventory:")
            print("----------------------------------------------")
            for product in self.products:
                if isinstance(product, TV):
                    print(f"Name: {product.name}")
                    print(f"Price: ${product.price}")
                    print(f"Quantity: {product.quantity}")
                    print(f"Brand: {product.brand}")
                    print(f"Size: {product.size} inches")
                    print(f"Resolution: {product.resolution}")
                    print("----------------------------------------------")

                
    def add_to_cart(self, name, quantity,type):
        if not self.user:
            print("----------------------------------------------")
            user=input("Enter your name : ")
            self.user.append(user)
        if not self.mobile:
            print("----------------------------------------------")
            mobile=input("Enter your mobile number : ")
            if len(mobile)==10:
                self.mobile.append(mobile)
            else:
                print("Invalid Mobile Number.")
        if not self.address:
            print("----------------------------------------------")
            print("Enter Address like :- house number,soc name,area,city,state")
            address=input("Enter your address : ")
            self.address.append(address)
        for product in self.products:
            if product.name.lower() == name.lower():
                if product.quantity >= quantity:
                    product.quantity -= quantity
                    price = product.price
                    # Add the product to the cart
                    self.cart.append(type(name,price,quantity))
                    print(f"{quantity} - {product.name}(s) added to {self.user}'s cart.")
                    return
                else:
                    print("----------------------------------------------")
                    print(f"\tSorry, {self.user}.")
                    print(f"Insufficient quantity of {product.name} in inventory.")
                    print("----------------------------------------------")
                    return
        print("Product not found in inventory.")
        
    def remove_from_cart(self, name):
        if not self.cart:
            print("Cart is empty.")
            return
        for item in self.cart:
            if item.name.lower() == name.lower():
                for product in self.products:
                    if product.name.lower() == name.lower():
                            product.quantity += item.quantity
                self.cart.remove(item)
                print(f"{name} removed from your cart.")
                return
        print(f"{name} not found in your cart.")

    def display_cart(self):
        if not self.cart:
            print("Cart is empty.")
        else:
            print("\nProducts in Cart:")
            for cart in self.cart:
                print(cart)
                
    def product_billing(self):
        total_cost = 0
        if not self.cart:
            print("Cart is empty.")
            return
        print("\nItems in the cart:")
        print("Product Quantity\t\t\tProduct Name\t\t\tProduct Price\t\t\t")
        print("-----------------------------------------------------------------------------------------")
        for item in self.cart:
            total_cost += item.price * item.quantity
            print(f"{item.quantity} \t\t\t {item.name} \t\t\t ${item.price}")
        print(f"\nTotal Cost: ${total_cost:.2f}")
        payment_choice = input("\nChoose payment method:\n1. Cash on Delivery\n2. Online Payment\n3. Card Payment\n")
        
        if payment_choice == "1":
            print(f"Payment of ${total_cost:.2f} made through Cash on Delivery.")
        elif payment_choice == "2":
            otp = random.randint(1000, 9999)
            print(f"An OTP has been sent to your registered mobile number/email.")
            print("Your OTP is: ", otp)
            user_otp = input("Enter the OTP to complete the payment: ")
            if str(otp) == user_otp:
                print(f"Payment of ${total_cost:.2f} successfully made through Online Payment.")
            else:
                print("Incorrect OTP. Payment failed.")
        elif payment_choice == "3":
            print("Paying by Card")
            print(f"Total amount to be paid: ${total_cost:.2f}")
            card_number = input("Enter the card number: ")
            expiry_date = input("Enter the expiry date (MM/YY): ")
            cvv = input("Enter the CVV: ")
            print("Card payment processed successfully.")
        else:
            print("Invalid choice.")
            return
        
        self.cart.clear()


class ProductNotFoundException(Exception):
    pass


def main():
    inventory = Inventory()

    # Adding books
    inventory.add_product_book(Book("The Hitchhiker's Guide to the Galaxy", 12.99, 5, "Douglas Adams"))
    inventory.add_product_book(Book("To Kill a Mockingbird", 8.99, 3, "Harper Lee"))
    inventory.add_product_book(Book("1984", 9.99, 8, "George Orwell"))
    inventory.add_product_book(Book("The Great Gatsby", 7.99, 6, "F. Scott Fitzgerald"))
    inventory.add_product_book(Book("Harry Potter and the Sorcerer's Stone", 11.99, 10, "J.K. Rowling"))

    # Adding T-shirts
    inventory.add_product_tshirt(TShirt("Nike T-Shirt", 20.0, 10, "M", "Black"))
    inventory.add_product_tshirt(TShirt("Adidas T-Shirt", 22.0, 8, "L", "White"))
    inventory.add_product_tshirt(TShirt("Puma T-Shirt", 18.0, 12, "S", "Blue"))
    inventory.add_product_tshirt(TShirt("Under Armour T-Shirt", 25.0, 7, "XL", "Gray"))
    inventory.add_product_tshirt(TShirt("Reebok T-Shirt", 19.0, 9, "M", "Red"))

    # Adding pants
    inventory.add_product_pants(Pants("Levi's Jeans", 40.0, 15, 32, 34))
    inventory.add_product_pants(Pants("Wrangler Jeans", 38.0, 20, 34, 32))
    inventory.add_product_pants(Pants("Dockers Khakis", 35.0, 18, 30, 32))
    inventory.add_product_pants(Pants("Calvin Klein Jeans", 45.0, 12, 36, 34))
    inventory.add_product_pants(Pants("Lee Jeans", 36.0, 17, 33, 30))

    # Adding shoes
    inventory.add_product_shoes(Shoes("Adidas Sneakers", 50.0, 20, 10, "White"))
    inventory.add_product_shoes(Shoes("Nike Running Shoes", 60.0, 25, 9, "Black"))
    inventory.add_product_shoes(Shoes("Puma Sneakers", 55.0, 22, 11, "Gray"))
    inventory.add_product_shoes(Shoes("Reebok Shoes", 45.0, 18, 10, "Blue"))
    inventory.add_product_shoes(Shoes("Vans Sneakers", 40.0, 30, 8, "Red"))

    # Adding smartwatches
    inventory.add_product_smartwatch(Smartwatch("Fire-Boltt Ninja", 1099.0, 25, "Fire-Boltt", "Ninja", "300 mAh"))
    inventory.add_product_smartwatch(Smartwatch("Apple Watch Series 6", 399.0, 15, "Apple", "Series 6", "500 mAh"))
    inventory.add_product_smartwatch(Smartwatch("Samsung Galaxy Watch", 299.0, 20, "Samsung", "Galaxy Watch", "400 mAh"))
    inventory.add_product_smartwatch(Smartwatch("Fitbit Versa 3", 229.0, 18, "Fitbit", "Versa 3", "350 mAh"))
    inventory.add_product_smartwatch(Smartwatch("Garmin Forerunner 245", 299.0, 10, "Garmin", "Forerunner 245", "300 mAh"))

    # Adding TVs
    inventory.add_product_tv(TV("Samsung QLED 4K Smart TV", 999.0, 5, "Samsung", 55, "4K"))
    inventory.add_product_tv(TV("LG OLED 4K Smart TV", 1499.0, 8, "LG", 65, "4K"))
    inventory.add_product_tv(TV("Sony LED 4K Smart TV", 1199.0, 7, "Sony", 50, "4K"))
    inventory.add_product_tv(TV("TCL Roku Smart TV", 599.0, 10, "TCL", 43, "1080p"))
    inventory.add_product_tv(TV("Vizio UHD Smart TV", 799.0, 12, "Vizio", 60, "4K"))

    while True:
        print("\nWelcome to our Online Store!")
        print("----------------------------")
        print("What would you like to do?")
        print("1. Browse Products")
        print("2. Manage Cart")
        print("3. Exit")
        choice = input("Enter your choice: ")

        if choice == "1":
            print("\nBrowse Products:")
            print("1. Books")
            print("2. T-Shirts")
            print("3. Shoes")
            print("4. Pants")
            print("5. Smartwatches")
            print("6. TVs")
            print("7. All Product in Inventory")
            category_choice = input("Enter the category number to browse products (or '0' to go back): ")

            if category_choice == "1":
                inventory.display_products_books()
            elif category_choice == "2":
                inventory.display_products_tshirt()
            elif category_choice == "3":
                inventory.display_products_shoes()
            elif category_choice == "4":
                inventory.display_products_pants()
            elif category_choice == "5":
                inventory.display_products_smartwatch()
            elif category_choice == "6":
                inventory.display_products_tv()
            elif category_choice == "7":
                inventory.display_products()
            elif category_choice == "0":
                continue
            else:
                print("Invalid choice.")

        elif choice == "2":
            print("\nManage Cart:")
            print("1. Add Product to Cart")
            print("2. Remove Product from Cart")
            print("3. View Cart")
            print("4. Proceed to Billing")
            print("5. Back to Main Menu")
            cart_choice = input("Enter your choice: ")

            if cart_choice == "1":
                name = input("Enter Product Name: ")
                quantity = int(input("Enter Quantity: "))
                inventory.add_to_cart(name, quantity, Product)
            elif cart_choice == "2":
                name = input("Enter Product Name: ")
                inventory.remove_from_cart(name)
            elif cart_choice == "3":
                inventory.display_cart()
            elif cart_choice == "4":
                inventory.product_billing()
            elif cart_choice == "5":
                continue
            else:
                print("Invalid choice.")

        elif choice == "3":
            print("Thank you for visiting our store! Have a great day!")
            break

        else:
            print("Invalid choice. Please try again.")
                    
main()
# Out:
# Welcome to our Online Store!
# ----------------------------
# What would you like to do?
# 1. Browse Products
# 2. Manage Cart
# 3. Exit
# Enter your choice:  1
# Browse Products:
# 1. Books
# 2. T-Shirts
# 3. Shoes
# 4. Pants
# 5. Smartwatches
# 6. TVs
# 7. All Product in Inventory
# Enter the category number to browse products (or '0' to go back):  1
# Books in inventory:
# ----------------------------------------------
# Name: The Hitchhiker's Guide to the Galaxy
# Price: $12.99
# Quantity: 5
# Author: Douglas Adams
# ----------------------------------------------
# Name: To Kill a Mockingbird
# Price: $8.99
# Quantity: 3
# Author: Harper Lee
# ----------------------------------------------
# Name: 1984
# Price: $9.99
# Quantity: 8
# Author: George Orwell
# ----------------------------------------------
# Name: The Great Gatsby
# Price: $7.99
# Quantity: 6
# Author: F. Scott Fitzgerald
# ----------------------------------------------
# Name: Harry Potter and the Sorcerer's Stone
# ...
